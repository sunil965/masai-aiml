# %% [markdown]
# <a href="https://colab.research.google.com/github/sunil965/masai-aiml/blob/master/M6C2%20Foundational%20Prompt%20Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prompting

# %%
# Prompt1: Tell me about SQL

# Prompt2: Explain SQL to a first-year engineering student who has never learnt it before.
# Use simple language with as less jargons as possible. Give 3 examples of it.

# Why is 2nd prompt better?
# It provides:
# - What is the actual task
# - Also tells who the target audience is (Context)
# - Gives proper limitations/rules to be followed (constraints)
# - It asks for examples.

# %%
# Prompt:

# It is the input or instructions that we provide to an AI model.
# User input --> AI Model --> Model output


# Prompting:
# Process of creating a prompt.

# %%
# # 3 examples where creativity/imagination would be preferred (feature)
# # and 3 where it would be not good.


# 1- For the tasks, which are creative in nature:
# - sotrytelling
# - advertisements
# - blog writing
# - marketing
# - image generation
# etc


# 2 - Its not preferred where there is less subjectivity, logic or rule based tasks.

# - coding
# - maths
# - facts
# - medical reasoning
# - legal matters
# etc

# %%
# Ingrediants of a better prompt:

# 1- Role
# 2 - Task
# 3 - Context
# 4- Contraints
# 5- Output format

# %%
# 1 - Role: Telling the model the persona/or the role that it should take
# eg:
# SQL developer
# Python Instructor
# Manager
# Financial Advisor
# Medial Professional

# etc

# %%
# 2 - Task: telling the AI model what exactly do you want it to do?
# - Joins concept in SQL
# - Teach me the OOPs concept in Python

# %%
# 3 - Context: Give me a 5 slide presentation on ML.

# Context1: for the non-technical first year MBA students.
# Cotnext2: for my Interview presentation with a IT firm.

# %%
# 4. Contraints: explain GenAI
# contraint1: within 200 words for a MBA student
# contraint2: with atleast 500 words to get some content around blog writing for the tech enthusiasts.

# %%
# 5. Output formats:

# Give GenAI Roadmap:
# - 1 paragraph
# - summary
# - tabular format

# %%
# Role: Act as a beginner-friendly Python Instructor
# Task: Explain Lists in Python
# Context: first-year Engineering students who have never programmed before
# Constraints: Use simple language, avoid jargons as much as possible.
# Format: Include variety of coding examples.

# %%
# Strategy1: Be as specific as possible.
#Strategy2: Specify the target audience.
#Strategy3: Give relevant examples: whenever need personalization: writing an email, creating a linkedin post
# with your own vocabulary and writing style ,etc
#Strategy4: defining your tone:
# - professional --> email to Manager
# -friendly --> generating a birthday invite
# - educational --> Youtube course creation thumbnail
#Strategy5: specify the length:
# write a blog within 100 words
# - give me a linkedin post on importance of AI upskilling in 5 bullet points
